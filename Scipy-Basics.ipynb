# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from scipy import linalg
import scipy.integrate
from numpy import exp
from scipy.interpolate import interp1d
from scipy import interpolate

# %%
a=np.array([[1,2,3],[4,5,-6],[7,7,4]])
b=np.array([1,2,3])

# %%
x=linalg.solve(a,b)
x
# Out:
# array([-0.09333333,  0.50666667,  0.02666667])

# %%
f=lambda x:100
i=scipy.integrate.quad(f,1,3)
i
# Out:
# (200.0, 2.220446049250313e-12)

# %%
f=lambda x:exp(-x**2)
i=scipy.integrate.quad(f,1,3)
i
# Out:
# (0.13938321544709423, 1.547464550356528e-15)

# %%
x=np.linspace(0,4,12)
y=np.cos(x**2/3+4)
x,y
plt.plot(x,y,'o')
# Out:
# (array([0.        , 0.36363636, 0.72727273, 1.09090909, 1.45454545,
#         1.81818182, 2.18181818, 2.54545455, 2.90909091, 3.27272727,
#         3.63636364, 4.        ]),
#  array([-0.65364362, -0.61966189, -0.51077021, -0.31047698, -0.00715476,
#          0.37976236,  0.76715099,  0.99239518,  0.85886263,  0.27994201,
#         -0.52586509, -0.99582185]))

# %%
f1=interp1d(x,y,kind='linear')
f2=interp1d(x,y,kind='cubic')
xnew=np.linspace(0,4,30)
plt.plot(x,y,'o',xnew,f1(xnew),'-',xnew,f2(xnew),'--')
plt.legend(['data','linear','cubic','nearest'],loc='best')
plt.show()
# Out:
# [<matplotlib.lines.Line2D at 0x1817ecd470>,
#  <matplotlib.lines.Line2D at 0x1817eddeb8>,
#  <matplotlib.lines.Line2D at 0x1817ee72b0>]
